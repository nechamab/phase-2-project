# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# # Overview
#
# This project will utilize movie data from various sources to create recommendations for a company to take to create a movie studio. It will draw findings from analysis to determine the best metrics to focus on for the recommendations.

# %%
# import needed libraries
import pandas as pd
import sqlite3

# %% [markdown]
# # Data Sources
#
# - Box Office Mojo
# - Rotten Tomatoes
# - The Movie Database
# - The Numbers
# - IMDB

# %% [markdown]
# Let's go through each dataset and see what we have.

# %% [markdown]
# ## BOX OFFICE MOJO

# %%
bom_movie_gross_df = pd.read_csv('/Users/nechamaborisute/Desktop/phase-2-project/zippedData/bom.movie_gross.csv.gz', compression  = 'gzip')

# %%
bom_movie_gross_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
bom_movie_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
bom_movie_gross_df.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %% [markdown]
# There are 3387 records in this dataframe and each represent a movie with title, studio, domestic gross, foriegn gross, and year it was released.
#
# columns:
# - title: movie title
# - studio: name of the studio
# - domestic gross: money made domestically
# - foreign gross: money made foreignly
#     - third are nulls
# - year: year movie was released

# %%
bom_movie_gross_df.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %% [markdown]
# Going to drop the nulls in all columns because there aren't too many, with the exception of foriegn gross but ill drop them for now and see what info the other datasets have.

# %%
bom_movie_gross_df = bom_movie_gross_df.dropna()

# %%
bom_movie_gross_df.isna().sum()
# Out:
# title             0
# studio            0
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %%
bom_movie_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2007 entries, 0 to 3353
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2007 non-null   object
#  1   studio          2007 non-null   object
#  2   domestic_gross  2007 non-null   float64
#  3   foreign_gross   2007 non-null   object
#  4   year            2007 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 94.1+ KB

# %% [markdown]
# This clean data set consists of 2007 records.

# %% [markdown]
# ## ROTTEN TOMATOES

# %%
rt_movie_info = pd.read_csv('/Users/nechamaborisute/Desktop/phase-2-project/zippedData/rt.movie_info.tsv.gz', compression = 'gzip', sep = '\t')

# %%
rt_movie_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
rt_movie_info.shape
# Out:
# (1560, 12)

# %%
rt_movie_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %% [markdown]
# The Rotten Tomatoes movie info dataset includes 1560 records where each record represents a movie, with id, rating, director, writer, box office, and studio as some of the columns.
#
# There seem to be lots of nulls in important columns such as studio and box office so may not use this dataset.

# %%
rt_reviews = pd.read_csv('/Users/nechamaborisute/Desktop/phase-2-project/zippedData/rt.reviews.tsv.gz', compression = 'gzip', sep = '\t', encoding = 'latin') # encoding is utf8?

# %%
rt_reviews.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
rt_reviews.shape
# Out:
# (54432, 8)

# %%
rt_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          54432 non-null  int64
#  1   review      48869 non-null  object
#  2   rating      40915 non-null  object
#  3   fresh       54432 non-null  object
#  4   critic      51710 non-null  object
#  5   top_critic  54432 non-null  int64
#  6   publisher   54123 non-null  object
#  7   date        54432 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %% [markdown]
# The Rotten Tomatoes reviews dataset includes 54432 records where each record represents a movie.
#
# The columns include id, review, rating, fresh, critic, top critic, publisher, and date.
#
# A better measure of success is box office payout so ratings won't be a specific target metric we will focus on.

# %% [markdown]
# ## THE MOVIE DB

# %%
tmdb_movies = pd.read_csv('/Users/nechamaborisute/Desktop/phase-2-project/zippedData/tmdb.movies.csv.gz', compression = 'gzip', index_col  = 0 )

# %%
tmdb_movies.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
tmdb_movies.shape
# Out:
# (26517, 9)

# %%
tmdb_movies.info() # no nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26517 entries, 0 to 26516
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          26517 non-null  object
#  1   id                 26517 non-null  int64
#  2   original_language  26517 non-null  object
#  3   original_title     26517 non-null  object
#  4   popularity         26517 non-null  float64
#  5   release_date       26517 non-null  object
#  6   title              26517 non-null  object
#  7   vote_average       26517 non-null  float64
#  8   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# The Movie DB dataset includes 26,517 records where each represents a movie.
#
# There are columns of id, genre ids, original language, original title, popularity, release date, title, vote average and vote count.
#
# There are no nulls in this dataset

# %% [markdown]
# ## THE NUMBERS

# %%
tn_movie_budgets = pd.read_csv('/Users/nechamaborisute/Desktop/phase-2-project/zippedData/tn.movie_budgets.csv.gz', compression = 'gzip')

# %%
tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
tn_movie_budgets.shape
# Out:
# (5782, 6)

# %%
tn_movie_budgets.info() # no nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
tn_movie_budgets.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  5782.000000       5.782000e+03    5.782000e+03     5.782000e+03
# mean     50.372363       3.158776e+07    4.187333e+07     9.148746e+07
# std      28.821076       4.181208e+07    6.824060e+07     1.747200e+08
# min       1.000000       1.100000e+03    0.000000e+00     0.000000e+00
# 25%      25.000000       5.000000e+06    1.429534e+06     4.125415e+06
# 50%      50.000000       1.700000e+07    1.722594e+07     2.798445e+07
# 75%      75.000000       4.000000e+07    5.234866e+07     9.764584e+07
# max     100.000000       4.250000e+08    9.366622e+08     2.776345e+09
#
#        total_profit
# count  5.782000e+03
# mean   5.989970e+07
# std    1.460889e+08
# min   -2.002376e+08
# 25%   -2.189071e+06
# 50%    8.550286e+06
# 75%    6.096850e+07
# max    2.351345e+09

# %% [markdown]
# The Numbers dataset includes 5782 records where each record represents a movie.
#
# The columns include id, release_date, movie, production_budget, domestic_gross and worldwide_gross.
#
# We can utilize the production budget and gross columns to determine profit.

# %% [markdown]
# ## INTERNET MOVIE DATABASE: IMDB

# %%
conn = sqlite3.connect('/Users/nechamaborisute/Desktop/phase-2-project/zippedData/im.db')

# %%
# %%bash
# sqlite3 /Users/nechamaborisute/Desktop/phase-2-project/zippedData/im.db
#
# .tables
# Out:
# box_office_mojo  movie_akas       persons
# directors        movie_basics     principals
# known_for        movie_ratings    writers

# %%
schema = pd.read_sql("""

SELECT *
FROM sqlite_schema 

""", conn)

# %%
schema
# Out:
#     type                      name         tbl_name  rootpage  \
# 0  table              movie_basics     movie_basics         2
# 1  table                 directors        directors         3
# 2  table                 known_for        known_for         4
# 3  table                movie_akas       movie_akas         5
# 4  table             movie_ratings    movie_ratings         6
# 5  table                   persons          persons         7
# 6  table                principals       principals         8
# 7  table                   writers          writers         9
# 8  table           box_office_mojo  box_office_mojo     41369
# 9  index  ix_box_office_mojo_index  box_office_mojo     41370
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...
# 8  CREATE TABLE "box_office_mojo" (\n"index" INTE...
# 9  CREATE INDEX "ix_box_office_mojo_index"ON "box...

# %%
# table names
pd.read_sql("""SELECT name FROM sqlite_master WHERE type = 'table';""", conn)
# Out:
#               name
# 0     movie_basics
# 1        directors
# 2        known_for
# 3       movie_akas
# 4    movie_ratings
# 5          persons
# 6       principals
# 7          writers
# 8  box_office_mojo

# %%
pd.read_sql("""

SELECT * 
FROM movie_basics
LIMIT 5

""", conn)
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
pd.read_sql("""

SELECT *
FROM movie_basics
WHERE genres IS NULL

""", conn)
# Out:
#        movie_id                                      primary_title  \
# 0     tt0187902  How Huang Fei-hong Rescued the Orphan from the...
# 1     tt0253093                                       Gangavataran
# 2     tt0306058                                      Second Coming
# 3     tt0326592                                      The Overnight
# 4     tt0330811                                Regret Not Speaking
# ...         ...                                                ...
# 5403  tt9907396                Footloose in the Cotswolds - Part 1
# 5404  tt9907608                Footloose in the Cotswolds - Part 2
# 5405  tt9910922       Doctor Who Augmented Reality: Times Magazine
# 5406  tt9914942                         La vida sense la Sara Amat
# 5407  tt9916730                                             6 Gunn
#
#                                          original_title  start_year  \
# 0     How Huang Fei-hong Rescued the Orphan from the...        2011
# 1                                          Gangavataran        2018
# 2                                         Second Coming        2012
# 3                                         The Overnight        2010
# 4                                   Regret Not Speaking        2011
# ...                                                 ...         ...
# 5403                Footloose in the Cotswolds - Part 1        2016
# 5404                Footloose in the Cotswolds - Part 2        2016
# 5405       Doctor Who Augmented Reality: Times Magazine        2013
# 5406                         La vida sense la Sara Amat        2019
# 5407                                             6 Gunn        2017
#
#       runtime_minutes genres
# 0                 NaN   None
# 1               134.0   None
# 2                95.0   None
# 3                88.0   None
# 4                 NaN   None
# ...               ...    ...
# 5403            118.0   None
# 5404            102.0   None
# 5405              NaN   None
# 5406              NaN   None
# 5407            116.0   None
#
# [5408 rows x 6 columns]

# %%
pd.read_sql("""
DELETE
FROM movie_basics
WHERE genres IS NULL
""", conn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-0873e3dbcb2f> in <module>
# ----> 1 pd.read_sql("""
#       2 DELETE
#       3 FROM movie_basics
#       4 WHERE genres IS NULL
#       5 """, conn)
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     481
#     482     if isinstance(pandas_sql, SQLiteDatabase):
# --> 483         return pandas_sql.read_query(
#     484             sql,
#     485             index_col=index_col,
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1726         args = _convert_params(sql, params)
#    1727         cursor = self.execute(*args)
# -> 1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#    1730         if chunksize is not None:
#
# TypeError: 'NoneType' object is not iterable

# %%
pd.read_sql("""

SELECT COUNT(*)
FROM movie_basics
WHERE genres IS NULL


""", conn)
# Out:
#    COUNT(*)
# 0         0

# %%
pd.read_sql("""

SELECT COUNT(*) AS title_null_count
FROM movie_basics
WHERE primary_title IS NULL

""", conn)
# Out:
#    title_null_count
# 0                 0

# %% [markdown]
# - columns include movie id, primary title, original title, start year, runtime minutes and genres.
# > might drop these rows where genre is null since we need the genre unless we could combine with other dataframes to get the genre
# > runtime minutes we could recommend how long the movie should be

# %%
pd.read_sql("""

SELECT *
FROM directors
LIMIT 5

""", conn)
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0462036  nm1940585
# 2  tt0835418  nm0151540
# 3  tt0835418  nm0151540
# 4  tt0878654  nm0089502

# %%
pd.read_sql("""

SELECT COUNT(*) AS person_id_null_count
FROM directors
WHERE person_id IS NULL

""", conn)
# Out:
#    person_id_null_count
# 0                     0

# %% [markdown]
# - the director table includes movie id and person id
# - no nulls in director table

# %%
pd.read_sql("""

SELECT * 
FROM known_for

""", conn).head()
# Out:
#    person_id   movie_id
# 0  nm0061671  tt0837562
# 1  nm0061671  tt2398241
# 2  nm0061671  tt0844471
# 3  nm0061671  tt0118553
# 4  nm0061865  tt0896534

# %%
pd.read_sql("""

SELECT COUNT(*) AS movie_id_null_count
FROM known_for
WHERE movie_id IS NULL

""", conn).head()
# Out:
#    movie_id_null_count
# 0                    0

# %%
pd.read_sql("""

SELECT COUNT(*) AS person_id_null_count
FROM known_for
WHERE person_id IS NULL

""", conn).head()
# Out:
#    person_id_null_count
# 0                     0

# %% [markdown]
# - in known for table there are no nulls and it has  a person id in one column paired with the movie id of the movie their most known for

# %%
pd.read_sql("""

SELECT * 
FROM movie_akas
LIMIT 5

""", conn).head()
# Out:
#     movie_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg         None         None                0.0
# 1     None  imdbDisplay         None                0.0
# 2     None  imdbDisplay         None                0.0
# 3     None         None  short title                0.0
# 4     None  imdbDisplay         None                0.0

# %%
pd.read_sql("""

SELECT COUNT(*) types_null_count
FROM movie_akas
WHERE types IS NULL

""", conn).head()
# Out:
#    types_null_count
# 0            163256

# %%
pd.read_sql("""

SELECT COUNT(*) attrib_null_count
FROM movie_akas
WHERE attributes IS NULL

""", conn).head()
# Out:
#    attrib_null_count
# 0             316778

# %% [markdown]
# - the movie aka table contiains movie id, ordering, title, region, language, types, attributes, is original title
# - has bunch of nulls

# %%
pd.read_sql("""

SELECT * 
FROM movie_ratings

""", conn).head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
pd.read_sql("""

SELECT COUNT(*) AS avgrating_null_count
FROM movie_ratings
WHERE averagerating IS NULL

""", conn).head()
# Out:
#    avgrating_null_count
# 0                     0

# %%
pd.read_sql("""

SELECT COUNT(*) AS numvotes_null_count
FROM movie_ratings
WHERE numvotes IS NULL

""", conn).head()
# Out:
#    numvotes_null_count
# 0                    0

# %%
pd.read_sql("""

SELECT COUNT(*) AS id_null_count
FROM movie_ratings
WHERE movie_id IS NULL

""", conn).head()
# Out:
#    id_null_count
# 0              0

# %% [markdown]
# - the movie ratings table contains movie id, average rating and num votes
# - no nulls

# %%
pd.read_sql("""

SELECT * 
FROM persons
LIMIT 5

""", conn)
# Out:
#    person_id       primary_name birth_year death_year  \
# 0  nm0061671  Mary Ellen Bauder       None       None
# 1  nm0061865       Joseph Bauer       None       None
# 2  nm0062070         Bruce Baum       None       None
# 3  nm0062195       Axel Baumann       None       None
# 4  nm0062798        Pete Baxter       None       None
#
#                                  primary_profession
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator

# %% [markdown]
# - the persons table contains person id, primary name, birth year, death year and primary profession.
# - lots of nulls in birth and death columns

# %%
pd.read_sql("""

SELECT * 
FROM principals
LIMIT 5

""", conn)
# Out:
#     movie_id  ordering  person_id  category       job        characters
# 0  tt0111414         1  nm0246005     actor      None       ["The Man"]
# 1  tt0111414         2  nm0398271  director      None              None
# 2  tt0111414         3  nm3739909  producer  producer              None
# 3  tt0323808        10  nm0059247    editor      None              None
# 4  tt0323808         1  nm3579312   actress      None  ["Beth Boothby"]

# %%
pd.read_sql("""

SELECT COUNT(*)
FROM principals
WHERE characters IS NULL

""", conn)
# Out:
#    COUNT(*)
# 0    634826

# %% [markdown]
# - the principals table contains movie id, ordering, person id, category, job and characters.
# - lots of nulls in job and characters columns

# %%
pd.read_sql("""

SELECT *
FROM writers AS w
LIMIT 5 

""", conn)
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0438973  nm0175726
# 2  tt0438973  nm1802864
# 3  tt0462036  nm1940585
# 4  tt0835418  nm0310087

# %%
pd.read_sql("""

SELECT COUNT (*) writer_null_count
FROM writers AS w
WHERE person_id IS NULL

""", conn)
# Out:
#    writer_null_count
# 0                  0

# %%
pd.read_sql("""

SELECT COUNT (*) movie_id_null_count
FROM writers AS w
WHERE movie_id IS NULL

""", conn)
# Out:
#    movie_id_null_count
# 0                    0

# %% [markdown]
# - writers table contains movie id and person id
# - no nulls

# %% [markdown]
# The IMDB database is a relatively clean database with tables movie_basics, directors, known_for, movie_akas, movie_ratings, persons, principals and writers.

# %%
# dataframe name.to_sql("name for the table inside database", conn)
rt_movie_info.to_sql("rt_movie_info", conn)

# %%
pd.read_sql("""SELECT name FROM sqlite_master WHERE type = 'table';""", conn)
# Out:
#                 name
# 0       movie_basics
# 1          directors
# 2          known_for
# 3         movie_akas
# 4      movie_ratings
# 5            persons
# 6         principals
# 7            writers
# 8    box_office_mojo
# 9      rt_movie_info
# 10        rt_reviews
# 11       tmdb_movies
# 12  tn_movie_budgets

# %%
box_office_mojo.to_sql("box_office_mojo", conn)
rt_reviews.to_sql("rt_reviews", conn)
tmdb_movies.to_sql("tmdb_movies", conn)
tn_movie_budgets.to_sql("tn_movie_budgets", conn)

# %%
pd.read_sql("""
SELECT * 
FROM box_office_mojo
""", conn)
# Out:
#       index                                              title        studio  \
# 0         0                                        Toy Story 3            BV
# 1         1                         Alice in Wonderland (2010)            BV
# 2         2        Harry Potter and the Deathly Hallows Part 1            WB
# 3         3                                          Inception            WB
# 4         4                                Shrek Forever After          P/DW
# ...     ...                                                ...           ...
# 2002   3275                                    I Still See You           LGF
# 2003   3286                              The Catcher Was a Spy           IFC
# 2004   3309                                         Time Freak    Grindstone
# 2005   3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 2006   3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross foreign_gross  year
# 0        415000000.0     652000000  2010
# 1        334200000.0     691300000  2010
# 2        296000000.0     664300000  2010
# 3        292600000.0     535700000  2010
# 4        238700000.0     513900000  2010
# ...              ...           ...   ...
# 2002          1400.0       1500000  2018
# 2003        725000.0        229000  2018
# 2004         10000.0        256000  2018
# 2005         93200.0          5200  2018
# 2006         43200.0         30000  2018
#
# [2007 rows x 6 columns]

# %%
pd.read_sql("""

SELECT DISTINCT studio
FROM box_office_mojo

""", conn)
# Out:
#            studio
# 0              BV
# 1              WB
# 2            P/DW
# 3            Sum.
# 4            Par.
# ..            ...
# 167      Blue Fox
# 168        Aviron
# 169            VE
# 170    Grindstone
# 171  Darin Southa
#
# [172 rows x 1 columns]

# %%
pd.read_sql("""
SELECT COUNT(*) 
FROM box_office_mojo
WHERE foreign_gross IS NULL

""", conn)
# Out:
#    COUNT(*)
# 0         0

# %%
pd.read_sql("""

SELECT * 
FROM rt_reviews
LIMIT 15

""", conn)
# Out:
#     index  id                                             review rating  \
# 0       0   3  A distinctly gallows take on contemporary fina...    3/5
# 1       1   3  It's an allegory in search of a meaning that n...   None
# 2       2   3  ... life lived in a bubble in financial dealin...   None
# 3       3   3  Continuing along a line introduced in last yea...   None
# 4       4   3             ... a perverse twist on neorealism...    None
# 5       5   3  ... Cronenberg's Cosmopolis expresses somethin...   None
# 6       6   3  Quickly grows repetitive and tiresome, meander...      C
# 7       7   3  Cronenberg is not a director to be daunted by ...    2/5
# 8       8   3  Cronenberg's cold, exacting precision and emot...   None
# 9       9   3  Over and above its topical urgency or the bit ...   None
# 10     10   3  Cosmopolis" is a hypnotic examination of our m...   None
# 11     11   3  While not one of Cronenberg's stronger films, ...     B-
# 12     12   3  Robert Pattinson works mighty hard to make Cos...    2/4
# 13     13   3  The anger over the injustice of the financial ...      B
# 14     14   3  For those who like their Cronenberg thick and ...    3/4
#
#      fresh           critic  top_critic            publisher  \
# 0    fresh       PJ Nabarro           0      Patrick Nabarro
# 1   rotten   Annalee Newitz           0              io9.com
# 2    fresh     Sean Axmaker           0     Stream on Demand
# 3    fresh    Daniel Kasman           0                 MUBI
# 4    fresh             None           0         Cinema Scope
# 5    fresh  Michelle Orange           0     Capital New York
# 6   rotten   Eric D. Snider           0      EricDSnider.com
# 7   rotten     Matt Kelemen           0   Las Vegas CityLife
# 8    fresh     Sean Axmaker           0        Parallax View
# 9    fresh     Kong Rithdee           0         Bangkok Post
# 10   fresh     Tim Grierson           0             Deadspin
# 11   fresh     Emanuel Levy           0      EmanuelLevy.Com
# 12  rotten   Christian Toto           0        Big Hollywood
# 13   fresh     Robert Roten           0  Laramie Movie Scope
# 14   fresh      Marty Mapes           0          Movie Habit
#
#                   date
# 0    November 10, 2018
# 1         May 23, 2018
# 2      January 4, 2018
# 3    November 16, 2017
# 4     October 12, 2017
# 5   September 11, 2017
# 6        July 17, 2013
# 7       April 21, 2013
# 8       March 24, 2013
# 9        March 4, 2013
# 10   February 12, 2013
# 11    February 3, 2013
# 12    January 15, 2013
# 13     January 7, 2013
# 14    October 20, 2012

# %%
pd.read_sql("""

SELECT COUNT( DISTINCT id) AS unique_id 
FROM rt_reviews
LIMIT 15
""", conn)
# Out:
#    unique_id
# 0       1135

# %%
pd.read_sql("""

SELECT *
FROM rt_reviews
LIMIT 15
""", conn)
# Out:
#     index  id                                             review rating  \
# 0       0   3  A distinctly gallows take on contemporary fina...    3/5
# 1       1   3  It's an allegory in search of a meaning that n...   None
# 2       2   3  ... life lived in a bubble in financial dealin...   None
# 3       3   3  Continuing along a line introduced in last yea...   None
# 4       4   3             ... a perverse twist on neorealism...    None
# 5       5   3  ... Cronenberg's Cosmopolis expresses somethin...   None
# 6       6   3  Quickly grows repetitive and tiresome, meander...      C
# 7       7   3  Cronenberg is not a director to be daunted by ...    2/5
# 8       8   3  Cronenberg's cold, exacting precision and emot...   None
# 9       9   3  Over and above its topical urgency or the bit ...   None
# 10     10   3  Cosmopolis" is a hypnotic examination of our m...   None
# 11     11   3  While not one of Cronenberg's stronger films, ...     B-
# 12     12   3  Robert Pattinson works mighty hard to make Cos...    2/4
# 13     13   3  The anger over the injustice of the financial ...      B
# 14     14   3  For those who like their Cronenberg thick and ...    3/4
#
#      fresh           critic  top_critic            publisher  \
# 0    fresh       PJ Nabarro           0      Patrick Nabarro
# 1   rotten   Annalee Newitz           0              io9.com
# 2    fresh     Sean Axmaker           0     Stream on Demand
# 3    fresh    Daniel Kasman           0                 MUBI
# 4    fresh             None           0         Cinema Scope
# 5    fresh  Michelle Orange           0     Capital New York
# 6   rotten   Eric D. Snider           0      EricDSnider.com
# 7   rotten     Matt Kelemen           0   Las Vegas CityLife
# 8    fresh     Sean Axmaker           0        Parallax View
# 9    fresh     Kong Rithdee           0         Bangkok Post
# 10   fresh     Tim Grierson           0             Deadspin
# 11   fresh     Emanuel Levy           0      EmanuelLevy.Com
# 12  rotten   Christian Toto           0        Big Hollywood
# 13   fresh     Robert Roten           0  Laramie Movie Scope
# 14   fresh      Marty Mapes           0          Movie Habit
#
#                   date
# 0    November 10, 2018
# 1         May 23, 2018
# 2      January 4, 2018
# 3    November 16, 2017
# 4     October 12, 2017
# 5   September 11, 2017
# 6        July 17, 2013
# 7       April 21, 2013
# 8       March 24, 2013
# 9        March 4, 2013
# 10   February 12, 2013
# 11    February 3, 2013
# 12    January 15, 2013
# 13     January 7, 2013
# 14    October 20, 2012

# %%
pd.read_sql("""
SELECT *
FROM rt_movie_info
LIMIT 15
""", conn)
# Out:
#     index  id                                           synopsis rating  \
# 0       0   1  This gritty, fast-paced, and innovative police...      R
# 1       1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2       2   5  Illeana Douglas delivers a superb performance ...      R
# 3       3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4       4   7                                               None     NR
# 5       5   8  The year is 1942. As the Allies unite overseas...     PG
# 6       6  10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7       7  13  Stewart Kane, an Irishman living in the Austra...      R
# 8       8  14  "Love Ranch" is a bittersweet love story that ...      R
# 9       9  15  When a diamond expedition in the Congo is lost...  PG-13
# 10     10  17                                               None   None
# 11     11  18  In 1979, Bill Viola and Frank Caliguri dreamed...     NR
# 12     12  19  While Microsoft may be the biggest software co...     NR
# 13     13  20  Rachel (Britt Ekland) is an Amish girl who rej...  PG-13
# 14     14  21  Old-school comic Rodney "I get no respect" Dan...      R
#
#                                                 genre          director  \
# 0                 Action and Adventure|Classics|Drama  William Friedkin
# 1                   Drama|Science Fiction and Fantasy  David Cronenberg
# 2                   Drama|Musical and Performing Arts    Allison Anders
# 3                          Drama|Mystery and Suspense    Barry Levinson
# 4                                       Drama|Romance    Rodney Bennett
# 5                               Drama|Kids and Family       Jay Russell
# 6                                              Comedy       Jake Kasdan
# 7                                               Drama      Ray Lawrence
# 8                                               Drama   Taylor Hackford
# 9   Action and Adventure|Mystery and Suspense|Scie...    Frank Marshall
# 10                                               None              None
# 11                                        Documentary              None
# 12                       Documentary|Special Interest              None
# 13                              Classics|Comedy|Drama  William Friedkin
# 14                                             Comedy     Peter Baldwin
#
#                                          writer  theater_date      dvd_date  \
# 0                                Ernest Tidyman   Oct 9, 1971  Sep 25, 2001
# 1                  David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013
# 2                                Allison Anders  Sep 13, 1996  Apr 18, 2000
# 3               Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997
# 4                                  Giles Cooper          None          None
# 5                               Gail Gilchriest   Mar 3, 2000  Jul 11, 2000
# 6                                    Mike White  Jan 11, 2002  Jun 18, 2002
# 7              Raymond Carver|Beatrix Christian  Apr 27, 2006   Oct 2, 2007
# 8                                 Mark Jacobson  Jun 30, 2010   Nov 9, 2010
# 9                          John Patrick Shanley   Jun 9, 1995  Jul 27, 1999
# 10                                         None          None          None
# 11                                 Robert Zullo          None          None
# 12                                         None  Aug 23, 2002  Sep 30, 2003
# 13  Sidney Michaels|Arnold Schulman|Norman Lear  Dec 22, 1968  May 20, 2008
# 14               Rodney Dangerfield|Harry Basil  Jan 31, 1997  Sep 20, 1999
#
#    currency  box_office      runtime                      studio
# 0      None        None  104 minutes                        None
# 1         $     600,000  108 minutes           Entertainment One
# 2      None        None  116 minutes                        None
# 3      None        None  128 minutes                        None
# 4      None        None  200 minutes                        None
# 5      None        None   95 minutes       Warner Bros. Pictures
# 6         $  41,032,915   82 minutes          Paramount Pictures
# 7         $     224,114  123 minutes      Sony Pictures Classics
# 8         $     134,904  117 minutes                        None
# 9      None        None  108 minutes                        None
# 10     None        None         None                        None
# 11     None        None         None  Showtime Documentary Films
# 12     None        None   90 minutes       Seventh Art Releasing
# 13     None        None   97 minutes                        None
# 14     None        None  106 minutes                        None

# %%
pd.read_sql("""

SELECT DISTINCT genre_ids
FROM tmdb_movies

""", conn)
# Out:
#                          genre_ids
# 0                  [12, 14, 10751]
# 1              [14, 12, 16, 10751]
# 2                    [12, 28, 878]
# 3                  [16, 35, 10751]
# 4                    [28, 878, 12]
# ...                            ...
# 2472        [18, 10751, 36, 10402]
# 2473                      [14, 80]
# 2474  [18, 14, 27, 878, 10749, 53]
# 2475                [16, 27, 9648]
# 2476               [10751, 12, 28]
#
# [2477 rows x 1 columns]

# %%
pd.read_sql("""

SELECT DISTINCT genre_ids
FROM tmdb_movies

""", conn)

# %%
pd.read_sql("""

SELECT *
FROM tn_movie_budgets
LIMIT 15
""", conn)
# Out:
#     index  id  release_date                                        movie  \
# 0       0   1  Dec 18, 2009                                       Avatar
# 1       1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2       2   3   Jun 7, 2019                                 Dark Phoenix
# 3       3   4   May 1, 2015                      Avengers: Age of Ultron
# 4       4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 5       5   6  Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# 6       6   7  Apr 27, 2018                       Avengers: Infinity War
# 7       7   8  May 24, 2007   Pirates of the Caribbean: At Worldâs End
# 8       8   9  Nov 17, 2017                               Justice League
# 9       9  10   Nov 6, 2015                                      Spectre
# 10     10  11  Jul 20, 2012                        The Dark Knight Rises
# 11     11  12  May 25, 2018                      Solo: A Star Wars Story
# 12     12  13   Jul 2, 2013                              The Lone Ranger
# 13     13  14   Mar 9, 2012                                  John Carter
# 14     14  15  Nov 24, 2010                                      Tangled
#
#    production_budget domestic_gross worldwide_gross
# 0       $425,000,000   $760,507,625  $2,776,345,279
# 1       $410,600,000   $241,063,875  $1,045,663,875
# 2       $350,000,000    $42,762,350    $149,762,350
# 3       $330,600,000   $459,005,868  $1,403,013,963
# 4       $317,000,000   $620,181,382  $1,316,721,747
# 5       $306,000,000   $936,662,225  $2,053,311,220
# 6       $300,000,000   $678,815,482  $2,048,134,200
# 7       $300,000,000   $309,420,425    $963,420,425
# 8       $300,000,000   $229,024,295    $655,945,209
# 9       $300,000,000   $200,074,175    $879,620,923
# 10      $275,000,000   $448,139,099  $1,084,439,099
# 11      $275,000,000   $213,767,512    $393,151,347
# 12      $275,000,000    $89,302,115    $260,002,115
# 13      $275,000,000    $73,058,679    $282,778,100
# 14      $260,000,000   $200,821,936    $586,477,240

# %%
# tmdb_genre_dictionary = {
#         28: 'Action',
#         12: 'Adventure',
#         16: 'Animation',
#         35: 'Comedy',
#         80: 'Crime',
#         99: 'Documentary',
#         18: 'Drama',
#         10751: 'Family',
#         14: 'Fantasy',
#         36: 'History',
#         27: 'Horror',
#         10402: 'Music',
#         9648: 'Mystery',
#         10749: 'Romance',
#         878: 'Science Fiction',
#         10770: 'TV Movie',
#         53: 'Thriller',
#         10752: 'War',
#         37: 'Western'
# }

# %%
conn.close()

# %% [markdown]
# # Summary
#
# As we can see, some these datasets include very useful information that we can use to draw helpful insights from, yet some are beyond the scope of the metrics we wish to focus on. For that reason, in the next notebook we will be analyzing and visualizing the data and drawing subsequent conclusions from the relevant datasets.
